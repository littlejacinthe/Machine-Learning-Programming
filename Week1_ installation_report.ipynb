# %% [markdown]
# # Environment installation

# %%
from IPython.display import Image

# %% [markdown]
# ### d2l environment has been created, jupyter notebook is installed

# %%
Image(r'C:\Users\jacin\Pictures\conda_install.png')

# %% [markdown]
# mxnet has been installed as well

# %%
import mxnet
