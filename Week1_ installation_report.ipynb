# %% [markdown]
# # Environment installation

# %%
from IPython.display import Image

# %% [markdown]
# ### Create d2l environment

# %%
Image(r'C:\Users\jacin\Pictures\create_env.png')

# %% [markdown]
# ## Activate d2l, download python

# %%
Image(r'C:\Users\jacin\Pictures\python_install.png')

# %% [markdown]
# ## Install Mxnet GPU

# %%
Image(r'C:\Users\jacin\Pictures\mxnet_gpu_install.png')

# %% [markdown]
# ## Install d2l package

# %%
Image(r'C:\Users\jacin\Pictures\d2l_install.png')

# %% [markdown]
# ## Open Jupyter Notebook

# %%
Image(r'C:\Users\jacin\Pictures\jupyter_open.png')
